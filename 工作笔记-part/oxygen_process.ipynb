# %%
content = ''
with open('../dataset/oxygen.txt', encoding='utf-8') as f:
    for l in f:
        nl = l.strip().replace(' ', '')
        content += nl
# print(content)
content = content.split("AA550F0702")[1:-1]
# print(content)
hexstr = ''
for i in content:
    hexstr += i[:12]
print(hexstr)
# Out:
# ...

# %%
bs = bytes.fromhex(hexstr)
data = []
for i in bs:
    data.append(i)
data=data[:7000]
data
# Out:
# [44,
#  41,
#  38,
#  36,
#  33,
#  208,
#  31,
#  29,
#  26,
#  24,
#  23,
#  58,
#  21,
#  19,
#  18,
#  17,
#  17,
#  216,
#  18,
#  19,
#  24,
#  34,
#  49,
#  184,
#  68,
#  87,
#  101,
#  108,
#  108,
#  193,
#  103,
#  96,
#  90,
#  212,
#  79,
#  141,
#  73,
#  68,
#  64,
#  59,
#  55,
#  222,
#  51,
#  48,
#  44,
#  41,
#  38,
#  8,
#  36,
#  33,
#  31,
#  28,
#  26,
#  103,
#  24,
#  22,
#  21,
#  19,
#  18,
#  188,
#  16,
#  16,
#  17,
#  18,
#  21,
#  82,
#  28,
#  41,
#  58,
#  78,
#  95,
#  255,
#  105,
#  109,
#  106,
#  99,
#  93,
#  33,
#  215,
#  81,
#  76,
#  71,
#  66,
#  245,
#  62,
#  58,
#  54,
#  50,
#  47,
#  140,
#  43,
#  40,
#  36,
#  34,
#  31,
#  74,
#  29,
#  27,
#  25,
#  23,
#  21,
#  240,
#  20,
#  18,
#  17,
#  16,
#  17,
#  186,
#  17,
#  19,
#  24,
#  34,
#  49,
#  246,
#  68,
#  86,
#  100,
#  107,
#  107,
#  8,
#  102,
#  95,
#  89,
#  211,
#  78,
#  70,
#  73,
#  68,
#  64,
#  60,
#  56,
#  241,
#  53,
#  50,
#  47,
#  44,
#  41,
#  201,
#  38,
#  34,
#  32,
#  30,
#  28,
#  161,
#  26,
#  24,
#  22,
#  20,
#  19,
#  254,
#  17,
#  17,
#  18,
#  19,
#  21,
#  48,
#  29,
#  41,
#  58,
#  78,
#  95,
#  50,
#  106,
#  109,
#  106,
#  99,
#  93,
#  111,
#  215,
#  81,
#  76,
#  71,
#  66,
#  245,
#  62,
#  58,
#  55,
#  51,
#  49,
#  97,
#  46,
#  43,
#  40,
#  37,
#  34,
#  134,
#  31,
#  29,
#  27,
#  25,
#  23,
#  85,
#  21,
#  20,
#  18,
#  17,
#  17,
#  94,
#  18,
#  20,
#  25,
#  35,
#  50,
#  179,
#  69,
#  88,
#  102,
#  108,
#  108,
#  114,
#  103,
#  96,
#  89,
#  212,
#  78,
#  55,
#  73,
#  68,
#  64,
#  60,
#  56,
#  241,
#  53,
#  49,
#  46,
#  43,
#  40,
#  218,
#  38,
#  35,
#  32,
#  30,
#  28,
#  46,
#  25,
#  24,
#  22,
#  20,
#  18,
#  238,
#  17,
#  17,
#  17,
#  19,
#  22,
#  54,
#  29,
#  42,
#  59,
#  78,
#  95,
#  17,
#  105,
#  109,
#  105,
#  98,
#  91,
#  220,
#  213,
#  79,
#  74,
#  70,
#  65,
#  172,
#  61,
#  57,
#  54,
#  50,
#  47,
#  74,
#  44,
#  41,
#  38,
#  35,
#  32,
#  224,
#  30,
#  28,
#  26,
#  24,
#  22,
#  38,
#  21,
#  19,
#  17,
#  16,
#  16,
#  166,
#  17,
#  19,
#  23,
#  34,
#  48,
#  247,
#  67,
#  86,
#  100,
#  106,
#  106,
#  195,
#  101,
#  94,
#  88,
#  210,
#  77,
#  10,
#  71,
#  66,
#  62,
#  58,
#  54,
#  244,
#  51,
#  48,
#  45,
#  42,
#  39,
#  168,
#  36,
#  34,
#  31,
#  28,
#  26,
#  239,
#  24,
#  22,
#  21,
#  19,
#  17,
#  94,
#  16,
#  16,
#  16,
#  17,
#  19,
#  113,
#  27,
#  39,
#  56,
#  75,
#  92,
#  233,
#  102,
#  106,
#  103,
#  96,
#  89,
#  236,
#  212,
#  78,
#  72,
#  67,
#  63,
#  185,
#  58,
#  55,
#  51,
#  48,
#  45,
#  22,
#  42,
#  39,
#  36,
#  33,
#  31,
#  72,
#  28,
#  26,
#  24,
#  22,
#  20,
#  131,
#  18,
#  16,
#  15,
#  14,
#  14,
#  115,
#  15,
#  17,
#  22,
#  32,
#  47,
#  200,
#  65,
#  84,
#  98,
#  104,
#  105,
#  229,
#  100,
#  92,
#  86,
#  208,
#  75,
#  120,
#  70,
#  66,
#  61,
#  57,
#  53,
#  106,
#  49,
#  45,
#  42,
#  40,
#  37,
#  217,
#  35,
#  33,
#  31,
#  28,
#  26,
#  54,
#  24,
#  21,
#  19,
#  18,
#  16,
#  157,
#  15,
#  15,
#  16,
#  17,
#  19,
#  192,
#  27,
#  38,
#  55,
#  73,
#  90,
#  117,
#  100,
#  104,
#  101,
#  94,
#  88,
#  136,
#  210,
#  76,
#  71,
#  66,
#  61,
#  5,
#  57,
#  54,
#  51,
#  48,
#  45,
#  215,
#  42,
#  38,
#  35,
#  33,
#  30,
#  227,
#  28,
#  26,
#  24,
#  22,
#  21,
#  221,
#  19,
#  18,
#  17,
#  16,
#  16,
#  181,
#  17,
#  18,
#  23,
#  33,
#  47,
#  241,
#  65,
#  83,
#  97,
#  103,
#  103,
#  128,
#  98,
#  91,
#  85,
#  207,
#  74,
#  44,
#  69,
#  65,
#  61,
#  57,
#  53,
#  172,
#  50,
#  47,
#  44,
#  41,
#  38,
#  103,
#  36,
#  33,
#  31,
#  29,
#  26,
#  163,
#  24,
#  23,
#  21,
#  19,
#  18,
#  51,
#  17,
#  16,
#  16,
#  17,
#  20,
#  63,
#  27,
#  39,
#  56,
#  75,
#  91,
#  106,
#  101,
#  104,
#  101,
#  95,
#  89,
#  223,
#  211,
#  77,
#  71,
#  67,
#  62,
#  97,
#  58,
#  55,
#  52,
#  48,
#  46,
#  142,
#  43,
#  40,
#  38,
#  35,
#  32,
#  62,
#  29,
#  27,
#  25,
#  23,
#  21,
#  240,
#  20,
#  19,
#  17,
#  17,
#  17,
#  241,
#  18,
#  20,
#  25,
#  34,
#  48,
#  203,
#  65,
#  82,
#  95,
#  101,
#  101,
#  8,
#  96,
#  89,
#  84,
#  206,
#  73,
#  37,
#  68,
#  64,
#  59,
#  56,
#  52,
#  165,
#  49,
#  46,
#  43,
#  40,
#  37,
#  250,
#  35,
#  32,
#  30,
#  28,
#  26,
#  18,
#  24,
#  22,
#  21,
#  20,
#  18,
#  210,
#  17,
#  17,
#  18,
#  19,
#  22,
#  210,
#  29,
#  41,
#  58,
#  75,
#  91,
#  172,
#  100,
#  103,
#  100,
#  94,
#  88,
#  185,
#  210,
#  77,
#  72,
#  67,
#  63,
#  173,
#  59,
#  55,
#  52,
#  49,
#  46,
#  135,
#  43,
#  40,
#  37,
#  35,
#  33,
#  132,
#  31,
#  28,
#  27,
#  25,
#  23,
#  218,
#  22,
#  21,
#  19,
#  19,
#  19,
#  25,
#  20,
#  21,
#  26,
#  36,
#  49,
#  200,
#  67,
#  84,
#  97,
#  103,
#  104,
#  196,
#  98,
#  92,
#  85,
#  208,
#  74,
#  94,
#  69,
#  65,
#  61,
#  57,
#  54,
#  78,
#  51,
#  47,
#  45,
#  42,
#  39,
#  10,
#  36,
#  34,
#  32,
#  30,
#  28,
#  34,
#  26,
#  24,
#  23,
#  21,
#  20,
#  18,
#  19,
#  19,
#  20,
#  21,
#  24,
#  50,
#  31,
#  43,
#  59,
#  77,
#  93,
#  244,
#  102,
#  105,
#  102,
#  96,
#  91,
#  115,
#  213,
#  80,
#  75,
#  70,
#  65,
#  165,
#  61,
#  57,
#  53,
#  50,
#  46,
#  240,
#  43,
#  40,
#  38,
#  35,
#  33,
#  96,
#  30,
#  28,
#  25,
#  23,
#  21,
#  56,
#  19,
#  18,
#  16,
#  16,
#  16,
#  30,
#  18,
#  19,
#  25,
#  36,
#  51,
#  5,
#  70,
#  89,
#  103,
#  110,
#  110,
#  53,
#  104,
#  97,
#  91,
#  213,
#  79,
#  2,
#  73,
#  68,
#  63,
#  59,
#  55,
#  110,
#  51,
#  47,
#  44,
#  41,
#  38,
#  170,
#  35,
#  32,
#  30,
#  28,
#  26,
#  18,
#  24,
#  22,
#  20,
#  19,
#  17,
#  245,
#  16,
#  16,
#  16,
#  18,
#  21,
#  249,
#  29,
#  42,
#  60,
#  80,
#  96,
#  164,
#  106,
#  109,
#  106,
#  99,
#  93,
#  111,
#  215,
#  81,
#  75,
#  70,
#  65,
#  169,
#  61,
#  57,
#  53,
#  50,
#  47,
#  174,
#  44,
#  41,
#  38,
#  35,
#  33,
#  190,
#  30,
#  28,
#  26,
#  24,
#  22,
#  38,
#  20,
#  18,
#  17,
#  16,
#  16,
#  228,
#  18,
#  19,
#  25,
#  36,
#  51,
#  5,
#  71,
#  90,
#  103,
#  110,
#  110,
#  112,
#  104,
#  97,
#  90,
#  212,
#  78,
#  51,
#  73,
#  67,
#  63,
#  59,
#  55,
#  232,
#  52,
#  48,
#  45,
#  42,
#  39,
#  249,
#  37,
#  35,
#  32,
#  30,
#  28,
#  96,
#  26,
#  25,
#  23,
#  21,
#  19,
#  30,
#  18,
#  18,
#  18,
#  19,
#  22,
#  20,
#  30,
#  43,
#  60,
#  79,
#  95,
#  110,
#  104,
#  107,
#  104,
#  97,
#  91,
#  230,
#  213,
#  79,
#  74,
#  69,
#  65,
#  249,
#  60,
#  57,
#  53,
#  50,
#  47,
#  99,
#  44,
#  42,
#  39,
#  36,
#  34,
#  17,
#  32,
#  30,
#  28,
#  26,
#  23,
#  25,
#  21,
#  20,
#  18,
#  18,
#  18,
#  233,
#  19,
#  20,
#  26,
#  36,
#  51,
#  170,
#  69,
#  87,
#  100,
#  106,
#  106,
#  208,
#  100,
#  94,
#  87,
#  209,
#  76,
#  147,
#  71,
#  66,
#  62,
#  58,
#  54,
#  244,
#  51,
#  48,
#  45,
#  42,
#  39,
#  168,
#  37,
#  34,
#  32,
#  29,
#  28,
#  186,
#  26,
#  24,
#  22,
#  21,
#  19,
#  58,
#  18,
#  17,
#  18,
#  18,
#  21,
#  186,
#  29,
#  42,
#  59,
#  78,
#  94,
#  79,
#  104,
#  106,
#  103,
#  96,
#  90,
#  172,
#  212,
#  78,
#  73,
#  68,
#  63,
#  124,
#  59,
#  55,
#  52,
#  49,
#  46,
#  135,
#  43,
#  41,
#  38,
#  35,
#  32,
#  177,
#  30,
#  27,
#  26,
#  24,
#  ...]

# %%
import numpy as np

arr = np.array(data).reshape(-1,1000)
arr
# Out:
# array([[ 44,  41,  38, ...,  27,  26,  24],
#        [ 22, 160,  20, ...,  58,  18,  20],
#        [ 25,  35,  50, ..., 106, 104,  94],
#        ...,
#        [ 56, 226,  53, ...,  86,  35,  33],
#        [ 31,  29,  27, ...,  18,  17, 214],
#        [ 17,  17,  18, ...,  56,  75,  92]])

# %%
import pandas as pd

df = pd.DataFrame(arr)
df = df.T
df
# Out:
#        0    1    2    3    4    5   6
# 0     44   22   25   98   56   31  17
# 1     41  160   35   92  226   29  17
# 2     38   20   50  214   53   27  18
# 3     36   19  179   80   51  172  19
# 4     33   17   68   75   48   24  26
# ..   ...  ...  ...  ...  ...  ...  ..
# 995  177   17   91  235   40   21  37
# 996   30   18  102   70   38   20  39
# 997   27   58  106   66   86   18  56
# 998   26   18  104   62   35   17  75
# 999   24   20   94   59   33  214  92
#
# [1000 rows x 7 columns]

# %%
df.plot(subplots=True, figsize=(20, 21))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
import neurokit2 as nk
import matplotlib.pyplot as plt

df_clean=pd.DataFrame()
df_raw=pd.DataFrame()

for i in range(7):
    ppg = df[i]
    signals, info = nk.ppg_process(ppg, sampling_rate=100)
    # fig = nk.ppg_plot(signals)

    # signals['PPG_Raw'].plot()
    # signals['PPG_Clean'].plot()
    # signals.plot(subplots=True)
    # plt.show()

    df_clean[i] = signals['PPG_Clean']
    df_raw[i] = signals['PPG_Raw']

df_raw.plot(subplots=True,figsize=(20,21))
plt.savefig("PPG_Raw.png")

df_clean.plot(subplots=True,figsize=(20,21))
plt.savefig("PPG_Clean.png")

# %%
ls=list(df[6])
for i in ls:
    print(i,end=',')
# Out:
# 17,17,18,19,26,113,37,52,72,90,102,120,107,106,99,93,87,37,209,76,71,67,62,109,59,55,52,49,46,135,43,40,38,35,32,62,29,28,26,24,22,104,20,18,17,16,17,186,18,22,31,45,63,68,83,98,106,108,104,27,97,91,213,79,74,47,69,64,60,57,53,136,50,47,44,42,39,108,36,34,31,28,26,239,24,23,22,20,19,231,18,18,19,21,27,232,38,54,73,91,103,0,108,107,100,94,215,88,82,76,71,67,62,232,58,55,51,48,45,22,43,40,37,35,32,218,30,28,26,24,22,38,21,19,19,19,19,94,21,24,33,46,63,127,82,97,105,107,102,203,96,90,212,78,73,224,69,64,60,57,53,136,50,47,44,42,39,108,36,34,31,29,27,117,25,23,22,20,19,42,18,18,19,21,27,232,38,54,72,90,101,211,107,105,99,92,214,187,81,75,70,65,61,248,58,54,51,48,45,153,43,40,37,35,32,218,30,28,26,24,22,38,21,19,18,18,19,49,20,24,32,46,63,25,82,97,105,107,102,203,95,89,211,78,73,249,68,63,59,55,52,143,49,46,43,40,37,250,34,32,29,26,24,45,22,20,19,17,16,229,15,16,17,19,26,196,38,55,75,93,105,117,110,108,101,94,216,183,82,76,71,66,61,206,57,53,50,47,44,94,41,39,36,34,32,172,29,26,24,22,20,78,19,17,16,16,17,200,18,22,31,46,64,168,84,100,108,110,105,93,98,91,213,79,73,131,68,63,59,55,51,12,48,45,42,39,37,12,34,32,29,27,25,183,23,21,19,18,16,242,16,16,17,19,26,215,38,55,75,93,105,117,110,108,101,94,216,183,82,76,71,67,62,232,58,54,50,47,44,152,41,39,36,33,31,6,29,27,25,23,21,240,19,17,16,16,17,200,19,23,33,46,65,158,84,99,107,109,104,170,97,91,213,79,74,47,69,64,60,56,52,18,49,46,43,40,38,24,35,32,30,28,26,18,24,22,21,19,18,188,17,18,19,21,28,37,39,55,75,93,104,230,109,107,101,94,216,127,82,76,71,66,62,44,58,54,50,47,44,152,41,38,35,33,31,243,28,26,24,22,20,131,19,17,16,17,17,12,18,22,31,45,63,68,83,98,106,108,103,90,96,90,212,78,73,224,68,63,59,55,52,143,48,45,42,39,36,82,33,30,28,26,24,149,22,21,19,17,16,106,16,16,17,19,26,215,38,54,74,91,103,228,108,106,100,93,215,130,81,75,70,65,61,248,57,54,50,48,45,124,42,40,37,34,32,211,29,27,25,23,21,240,20,18,17,17,18,156,19,23,32,46,64,107,83,98,106,108,103,90,96,90,212,79,73,36,69,64,60,56,53,76,50,47,44,42,39,108,36,34,32,29,27,244,26,24,22,21,19,58,18,18,19,21,28,107,39,55,74,92,103,200,108,106,100,93,215,130,82,76,72,67,63,233,58,55,51,48,46,244,43,40,37,35,32,218,30,28,26,25,23,188,21,20,19,19,19,216,21,25,34,48,66,33,84,99,107,108,104,110,97,90,213,79,73,66,69,64,60,56,52,18,49,46,43,41,38,220,36,33,31,28,26,103,25,23,21,20,19,206,18,18,19,22,29,96,40,56,74,92,102,99,107,105,99,92,214,187,81,75,70,66,61,173,57,53,50,46,43,25,40,37,35,32,30,44,28,26,25,23,21,178,20,18,17,17,18,156,19,23,33,46,64,192,83,97,105,106,102,194,95,89,211,77,72,242,67,62,58,55,51,121,48,45,42,39,37,12,34,32,29,27,25,183,23,22,20,19,17,154,17,17,18,20,27,65,38,54,74,91,102,186,106,105,98,92,213,63,80,75,70,65,61,53,57,53,50,47,44,94,41,38,36,34,31,220,29,27,25,24,22,10,20,19,18,17,18,247,19,23,32,46,65,53,84,99,108,109,105,142,98,91,213,80,74,149,69,65,60,56,53,195,50,47,44,41,39,57,36,33,31,29,27,253,25,24,22,20,19,176,19,19,20,22,28,6,40,56,76,94,106,128,110,108,102,95,217,201,83,78,72,68,63,77,59,55,52,48,45,161,42,40,37,35,32,23,30,28,26,25,23,188,21,20,19,19,19,216,21,25,35,49,67,16,86,101,108,110,105,81,98,92,214,80,75,169,70,65,60,56,53,141,49,46,43,40,37,250,34,32,30,28,26,223,24,22,21,19,18,188,17,18,19,21,28,37,39,56,75,92,

# %% [markdown]
# ###### show result

# %%
df_clean_cs = pd.DataFrame()
for i in range(7):
    with open('./v{}.txt'.format(i), 'r') as f:
        data = []
        for l in f.readlines():
            data.append(float(l.strip()))
    # data=[i if i>0 else 0 for i in data ]
    df_clean_cs[i] = data
df_clean_cs
# Out:
#              0          1          2           3          4          5  \
# 0    43.999887  21.999943  24.999936   97.999747  55.999856  30.999920
# 1    43.973520  23.186277  25.085599   97.946886  57.460907  30.982321
# 2    43.816450  27.943728  25.645670   98.732997  63.315831  30.877544
# 3    43.364962  35.730325  28.404159  102.241417  72.875821  31.834687
# 4    42.494816  42.323390  36.024236  107.733936  80.901594  36.321050
# ..         ...        ...        ...         ...        ...        ...
# 995 -22.521219 -39.785114  20.039651   19.608524   1.858522 -40.106831
# 996 -21.591906 -37.857965  30.310592   25.496785   0.035754 -41.643729
# 997 -17.507747 -35.109923  38.875040   31.906458  -6.189496 -41.982972
# 998 -13.819495 -31.049536  44.467216   34.319068 -13.794196 -41.236552
# 999 -13.416702 -25.973898  46.810228   29.564495 -20.689083 -37.978427
#
#              6
# 0    16.999956
# 1    16.999736
# 2    17.007692
# 3    17.058069
# 4    17.259133
# ..         ...
# 995 -23.396673
# 996 -26.875018
# 997 -28.690001
# 998 -27.628233
# 999 -22.841606
#
# [1000 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
df_clean_cs.plot(subplots=True,figsize=(20,21))
plt.savefig("csharp_Clean.png")

# %%
df_ro_3 = df_clean_cs.rolling(window=3).mean()
df_ro_3
# Out:
#              0          1          2           3          4          5  \
# 0          NaN        NaN        NaN         NaN        NaN        NaN
# 1          NaN        NaN        NaN         NaN        NaN        NaN
# 2    43.929952  24.376649  25.243735   98.226543  58.925531  30.953262
# 3    43.718311  28.953443  26.378476   99.640433  64.550853  31.231517
# 4    43.225409  35.332481  30.024688  102.902783  72.364415  33.011094
# ..         ...        ...        ...         ...        ...        ...
# 995 -21.095259 -40.691706  13.494310   16.881759  -3.840335 -37.374332
# 996 -21.645293 -39.547001  20.657039   20.341643  -0.120381 -39.770874
# 997 -20.540291 -37.584334  29.741761   25.670589  -1.431740 -41.244510
# 998 -17.639716 -34.672475  37.884283   30.574104  -6.649313 -41.621084
# 999 -14.914648 -30.711119  43.384161   31.930007 -13.557592 -40.399317
#
#              6
# 0          NaN
# 1          NaN
# 2    17.002461
# 3    17.021832
# 4    17.108298
# ..         ...
# 995 -20.458815
# 996 -23.380701
# 997 -26.320564
# 998 -27.731084
# 999 -26.386613
#
# [1000 rows x 7 columns]

# %%
df_ro_3.plot(subplots=True,figsize=(20,21))
plt.savefig("df_ro_3.png")

# %%
fig =plt.figure(figsize=(20,3))
plt.plot(data,figure=fig)

# %%
data2 = []
step = 6
for i, v in enumerate(data):
    data2.append(sum(data[i:i + step]) / len(data[i:i + step]))

fig = plt.figure(figsize=(20, 3))
plt.plot(data2, figure=fig)
