# %% [markdown]
# 文档：https://pandas.pydata.org/docs/user_guide/visualization.html

# %% [markdown]
# # 线图

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()  # 累加
ts.plot()   # Series直接调用plot
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index,
                  columns=list('ABCD'))
df = df.cumsum()
plt.figure()
df.plot()     # 绘制所有列
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = pd.Series(list(range(len(df))))
df3
df3.plot(x='A', y='B')  # 指定xy为某两列
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# # 条形图 bar

# %%
plt.figure()
df.iloc[5].plot(kind="bar")
plt.axhline(0, color="k")

# %%
plt.figure()
df.iloc[5].plot.bar()
plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=list('abcd'))
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 直方图 histogram
# bar 分类数值
# histogram 频次统计

# %% [markdown]
# ## DataFrame.plot.hist() 和 Series.plot.hist()

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)
plt.figure()
df4.plot.hist(alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4['a'].plot.hist(orientation="horizontal", bins=20, cumulative=True)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %% [markdown]
# ## DataFrame.hist()
# 常用颜色简写（ color = 'b' ）
# b: 蓝色（blue）
#
# g: 绿色（green）
#
# r: 红色（red）
#
# c: 蓝绿色（cyan）
#
# m: 紫红色（magenta）
#
# y: 黄色（yellow）
#
# k: 黑色（black）
#
# w: 白色（white）

# %%
# dataframe的每一列一个子图
plt.figure();
df4.diff().hist(color="y", alpha=0.5, bins=50);  # bins 分几段

# %% [markdown]
# ## Series.hist()

# %%
plt.figure();
df4["a"].diff().hist();

# %%
# 使用by参数 分组统计
data = pd.Series(np.random.randn(1000))
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4));

# %%
data = pd.DataFrame(
    {
        "a": np.random.choice(["x", "y", "z"], 1000),
        "b": np.random.choice(["e", "f", "g"], 1000),
        "c": np.random.randn(1000),
        "d": np.random.randn(1000) - 1,
    },
)
data['c'].hist(by=data['a'].values, figsize=(10, 5))
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>],
#        [<AxesSubplot:title={'center':'z'}>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # 箱线图 box

# %%
df = pd.DataFrame(np.random.rand(10, 5))
plt.figure();
color = {
    "boxes": "DarkGreen",
    "whiskers": "DarkOrange",
    "medians": "DarkBlue",
    "caps": "Gray",
}
df.plot.box(color=color, sym="r+");

# %% [markdown]
# 四分位数：它是一组数据排序后处于25%和75%位置上的值。
#
# 箱线图和k线图区别
# ![箱线图](../img/箱线图.jpeg)
# ![k线图](../img/k线图.png)

# %% [markdown]
# # 面积图 Area plot

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list('abcd'))
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df['a'].plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 散点图 Scatter plot

# %% [markdown]
# ## 一组

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=list('abcd'))
df.plot.scatter(x='c',y='b')
# Out:
# <AxesSubplot:xlabel='c', ylabel='b'>

# %% [markdown]
# ## 多组

# %%
ax = df.plot.scatter(x='a', y='b', label='group  1', color='y')
df.plot.scatter(x='c', y='d', label='group 2', color='b', ax=ax)
# Out:
# <AxesSubplot:xlabel='c', ylabel='d'>

# %% [markdown]
# ## 色阶

# %%
# s size
df.plot.scatter(x='a', y='b', c='c', s=50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df["species"] = pd.Categorical(["setosa"] * 20 + ["versicolor"] * 20 +
                               ["virginica"] * 10)
df
# Out:
#            a         b         c         d     species
# 0   0.025067  0.126092  0.617946  0.241498      setosa
# 1   0.670811  0.147658  0.532989  0.557444      setosa
# 2   0.182932  0.126580  0.458061  0.709524      setosa
# 3   0.435656  0.695788  0.323879  0.562924      setosa
# 4   0.673205  0.165250  0.577092  0.352234      setosa
# 5   0.460529  0.586189  0.129818  0.627449      setosa
# 6   0.775569  0.904631  0.620877  0.944679      setosa
# 7   0.696513  0.543682  0.485062  0.894117      setosa
# 8   0.342322  0.238505  0.580044  0.886054      setosa
# 9   0.645230  0.916021  0.873440  0.160951      setosa
# 10  0.933595  0.113131  0.966661  0.041292      setosa
# 11  0.533379  0.034075  0.324821  0.751908      setosa
# 12  0.973342  0.728268  0.843881  0.343886      setosa
# 13  0.665852  0.638369  0.296215  0.885075      setosa
# 14  0.391493  0.050360  0.794152  0.491134      setosa
# 15  0.320018  0.939512  0.028881  0.373618      setosa
# ...

# %%
df['species'].dtype
# Out:
# CategoricalDtype(categories=['setosa', 'versicolor', 'virginica'], ordered=False)

# %%
# 不对？？
# df.plot.scatter(x="a", y="b", c="species", cmap="viridis", s=50);

# %%
df.plot.scatter(x='a', y='b', c='c', colormap='viridis')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ## 指定颜色

# %%
df.plot.scatter(x='a', y='b', c=['green', 'yellow'] * 25, s=50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a', y='b', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# ## 指定点大小

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # 六角形箱体图 Hexagonal bin plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a', y='b', gridsize=20)  # 正态分布
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['b'] = df['b'] + np.arange(1000)   # 增加干扰
df.plot.hexbin(x='a', y='b', gridsize=20)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df["z"] = np.random.uniform(0, 3, 1000)
df.plot.hexbin(x="a", y="b", C="z", reduce_C_function=np.max, gridsize=2)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %% [markdown]
# # 饼图 pie

# %% [markdown]
# ## series.plot.pie()

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
series.plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='series'>

# %%
series.plot.pie(labels=["AA", "BB", "CC", "DD"],
                colors=["r", "g", "b", "c"],
                autopct="%.2f",
                fontsize=20,
                figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='series'>

# %% [markdown]
# ## df.plot.pie()

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2),
                  index=["a", "b", "c", "d"],
                  columns=["x", "y"])
df.plot.pie(subplots=True, figsize=(8, 4))
# Out:
# array([<AxesSubplot:ylabel='x'>, <AxesSubplot:ylabel='y'>], dtype=object)

# %%
series = pd.Series([0.1] * 4 + [0.2],
                   index=["a", "b", "c", "d", "e"],
                   name="series2")
series.plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='series2'>

# %% [markdown]
# # 散点图矩阵
# diagonal 可选参数：
# - kde 核密度曲线  Kernel Density Estimation
# - hist 直方图
#
# 关于直方图和kde可参考：https://blog.csdn.net/unixtch/article/details/78556499

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde")
# Out:
# array([[<AxesSubplot:xlabel='a', ylabel='a'>,
#         <AxesSubplot:xlabel='b', ylabel='a'>,
#         <AxesSubplot:xlabel='c', ylabel='a'>,
#         <AxesSubplot:xlabel='d', ylabel='a'>],
#        [<AxesSubplot:xlabel='a', ylabel='b'>,
#         <AxesSubplot:xlabel='b', ylabel='b'>,
#         <AxesSubplot:xlabel='c', ylabel='b'>,
#         <AxesSubplot:xlabel='d', ylabel='b'>],
#        [<AxesSubplot:xlabel='a', ylabel='c'>,
#         <AxesSubplot:xlabel='b', ylabel='c'>,
#         <AxesSubplot:xlabel='c', ylabel='c'>,
#         <AxesSubplot:xlabel='d', ylabel='c'>],
#        [<AxesSubplot:xlabel='a', ylabel='d'>,
#         <AxesSubplot:xlabel='b', ylabel='d'>,
#         <AxesSubplot:xlabel='c', ylabel='d'>,
#         <AxesSubplot:xlabel='d', ylabel='d'>]], dtype=object)

# %%
scatter_matrix(df,alpha=0.2,figsize=(6,6),diagonal='hist',color='y')
# Out:
# array([[<AxesSubplot:xlabel='a', ylabel='a'>,
#         <AxesSubplot:xlabel='b', ylabel='a'>,
#         <AxesSubplot:xlabel='c', ylabel='a'>,
#         <AxesSubplot:xlabel='d', ylabel='a'>],
#        [<AxesSubplot:xlabel='a', ylabel='b'>,
#         <AxesSubplot:xlabel='b', ylabel='b'>,
#         <AxesSubplot:xlabel='c', ylabel='b'>,
#         <AxesSubplot:xlabel='d', ylabel='b'>],
#        [<AxesSubplot:xlabel='a', ylabel='c'>,
#         <AxesSubplot:xlabel='b', ylabel='c'>,
#         <AxesSubplot:xlabel='c', ylabel='c'>,
#         <AxesSubplot:xlabel='d', ylabel='c'>],
#        [<AxesSubplot:xlabel='a', ylabel='d'>,
#         <AxesSubplot:xlabel='b', ylabel='d'>,
#         <AxesSubplot:xlabel='c', ylabel='d'>,
#         <AxesSubplot:xlabel='d', ylabel='d'>]], dtype=object)

# %% [markdown]
# # 密度图 Density plot
# 可视化连续变量的分布

# %%
ser = pd.Series(np.random.randn(1000), name='ser1')
ser.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # 安德鲁斯曲线 Andrews curves
# 安德鲁斯曲线通过将每个观测数据映射到一个函数来可视化高维数据。 它保留了平均值，距离和方差。 由公式给出:
# ```
# T(n) = x_1/sqrt(2) + x_2 sin(n) + x_3 cos(n) + x_4 sin(2n) + x_5 cos(2n) + …
# ```

# %%
from pandas.plotting import andrews_curves

# iris数据集下载地址kaggle：
# https://www.kaggle.com/arshid/iris-flower-dataset/version/1
df = pd.read_csv('../dataset/IRIS.csv')
plt.figure()
andrews_curves(df, "species")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 平行坐标图 Parallel coordinates
# 数据集的一行数据在平行坐标图中用一条折线表示，纵向是属性值，横向是属性类别（用索引表示）
# ![平行坐标图解释](../img/平行坐标图解释.png)
#
# **平行坐标图的解读**
#
# 首先我们用不同的颜色来标识不同的标签，那么关于属性与标签之间的关系，我们可以从图中获得哪些信息？
#
# （1）折线走势“陡峭”与“低谷”只是表示在该属性上属性值的变化范围的大小，对于标签分类不具有决定意义，但是“陡峭“的属性上属性值间距较大，视觉上更容易区分出不同的标签类别
#
# （2）标签的分类主要看相同颜色的折线是否集中，若在某个属性上相同颜色折线较为集中，不同颜色有一定的间距，则说明该属性对于预测标签类别有较大的帮助
#
# （3）若某个属性上线条混乱，颜色混杂，则较大可能该属性对于标签类别判定没有价值
#
# 原文链接：https://blog.csdn.net/wyfcode/article/details/82587440

# %%
from pandas.plotting import parallel_coordinates

data = pd.read_csv('../dataset/IRIS.csv')
plt.figure()
parallel_coordinates(data, "species",colormap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 滞后图 lag plot
# 滞后图是用时间序列和相应的滞后阶数序列做出的散点图。可以用于观测自相关性。默认lag=1.即用后一个数和前一个数绘制散点图。
# figsize：以英寸为单位的元组（宽度，高度）
# 1英寸= 2.54厘米

# %%
from pandas.plotting import lag_plot

spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))
plt.figure(figsize=(3,3))
lag_plot(data)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
plt.figure(figsize=(3,3))
lag_plot(data, lag=5)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 5)'>

# %%
plt.figure(figsize=(3, 3))
lag_plot(data, lag=6)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 6)'>

# %% [markdown]
# # 绘图格式

# %% [markdown]
# ## 禁用图标
# legend=False

# %%
ts = pd.Series(index=pd.date_range('2000-1-1', periods=1000))
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index,
                  columns=list("ABCD"))
df = df.cumsum()
df.plot(legend=False)
# Out:
# D:\ProgramData\anaconda3\envs\ml37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:>

# %% [markdown]
# ## 设置xy标签

# %%
df.plot(xlabel='x',ylabel='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## 缩放坐标轴

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('01/01/2000', periods=1000))
ts = np.exp(ts.cumsum())
ts.plot(logy=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 次坐标轴

# %%
df['A'].plot()
df['B'].plot(secondary_y=True, style='g')
# Out:
# <AxesSubplot:>

# %%
plt.figure()
ax = df.plot(secondary_y=['A', 'B'])
ax.set_ylabel('CD Scale')
ax.right_ax.set_ylabel('AB Scale')
# Out:
# Text(0, 0.5, 'AB Scale')

# %% [markdown]
# ## 紧凑的x轴

# %%
plt.figure();
df["A"].plot(x_compat=True);

# %% [markdown]
# ## with语句

# %%
plt.figure()
with pd.plotting.plot_params.use("x_compat", True):
    df['A'].plot(legend=True)
    df['B'].plot()
    df['C'].plot()

# %% [markdown]
# ## 子图

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# ## 使用布局layout

# %%
df.plot(subplots=True, figsize=(10, 5), layout=(2, 3), sharex=False)
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.plot(subplots=True, figsize=(10, 5), layout=(2, -1), sharex=False)  # -1 自动推断
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.plot(subplots=True, figsize=(10, 5), layout=(-1, 3), sharex=False)
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# plt.subplots_adjust(wspace=0.5, hspace=0.5)
# wspace: 设置左右子图之间的距离
# hspace: 设置上下子图之间的距离

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 9))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]
target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]
df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False)
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# ## 表格
# 在plot方法里添加table=True参数

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
df = pd.DataFrame(np.random.rand(5, 3), columns=list('abc'))
ax.xaxis.tick_top()
df.plot(ax=ax, table=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 也可以给table参数传递dataframe或series

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
df = pd.DataFrame(np.random.rand(5, 3), columns=list('abc'))
ax.xaxis.tick_top()
df.plot(ax=ax, table=np.round(df.T, 2))
# Out:
# <AxesSubplot:>

# %%
type(np.round(df.T, 2))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 使用table方法

# %%
from pandas.plotting import table

fig,ax=plt.subplots(1,1)
table(ax,np.round(df.describe(),2),loc='upper right',colWidths=[0.2,0.2,0.2])
df.plot(ax=ax,ylim=(0,2),legend=None)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## colormap
# 可以直接传递colormap值，或者使用matplotlib里的cm

# %%
df.plot(colormap='winter')
# Out:
# <AxesSubplot:>

# %%
from matplotlib import cm

df.plot(colormap=cm.Set1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 其他类型的图也可以设置

# %%
df = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
df = df.cumsum()
df.plot.bar(colormap='Greens')
# Out:
# <AxesSubplot:>

# %%
df[0].map(abs)
# Out:
# 0    0.907473
# 1    1.850295
# 2    2.710410
# 3    4.314104
# 4    5.230468
# 5    5.510647
# 6    5.884000
# 7    7.823988
# 8    9.396919
# 9    9.784782
# Name: 0, dtype: float64
